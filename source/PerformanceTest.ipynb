# %%
# %pylab inline
import numpy as np
import sys
import AllocationModule as AM
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
#Poisson - BigBoss
ra_range = 3.0
fiber_pitch_mm = 7.56
fiber_size_mm = 3.6
patrol_radius_mm = 7.0
plate_scale = ra_range/75.0/fiber_pitch_mm
method="galaxy_density"
gal_density  = 2.0*(119.0*137.0/(ra_range**2))
mock_gals = AM.MockGalaxyCatalog(number_density=gal_density, ra_range = ra_range, dec_range=ra_range, random=True)
mock_gals.tile_ID[:] = -1
for i in range(5):    
    BB_fibers = AM.FiberSet(Nx=75, Ny=87,fiber_pitch=fiber_pitch_mm * plate_scale, fiber_size=fiber_size_mm * plate_scale, rectangle=True)
    AM.make_fiber_allocation(BB_fibers, mock_gals, visit_ID=i, rank_criterion=method, patrol_radius=patrol_radius_mm * plate_scale,\
                    exclusion_radius=BB_fibers.fiber_size * 0.5)
    allocated_gals = where(mock_gals.visit_ID!=-2)
    n_allocated = size(allocated_gals)
    n_total_gals = 1.0*mock_gals.Ngalaxies
    print 'fraction of allocated galaxies', n_allocated/n_total_gals, n_total_gals, BB_fibers.Nfibers
scatter(BB_fibers.x, BB_fibers.y, color='blue', alpha=1.0, s=1.0)
# Out:
# 2409 fibers were reset
# 993
#  fibers were reset
# 331
#  fibers were reset
# 192
#  fibers were reset
# 183
#  fibers were reset
# 182
#  fibers were reset
# 182
#  fibers were reset
# fraction of allocated galaxies 0.194534748206 32606.0 6525
# 2693
#  fibers were reset
# 1011
#  fibers were reset
# 351
#  fibers were reset
# 249
#  fibers were reset
# 230
#  fibers were reset
# 228
#  fibers were reset
# 228
#  fibers were reset
# fraction of allocated galaxies 0.38765871312 32606.0 6525
# 2976
#  fibers were reset
# 1151
#  fibers were reset
# 430
#  fibers were reset
# 297
#  fibers were reset
# 276
#  fibers were reset
# 274
#  fibers were reset
# 273
#  fibers were reset
# 273
#  fibers were reset
# fraction of allocated galaxies 0.579310556339 32606.0 6525
# 3025
#  fibers were reset
# 1183
#  fibers were reset
# 476
#  fibers were reset
# 368
#  fibers were reset
# 351
#  fibers were reset
# 350
#  fibers were reset
# fraction of allocated galaxies 0.767619456542 32606.0 6525
# 3150
#  fibers were reset
# 1323
#  fibers were reset
# 640
#  fibers were reset
# 543
#  fibers were reset
# 520
#  fibers were reset
# 518
#  fibers were reset
# 517
#  fibers were reset
# fraction of allocated galaxies 0.924799116727 32606.0 6525

# %%
#Poisson - Echidna
ra_range = 3.0
fiber_pitch_mm = 7.56
fiber_size_mm = 1.2
patrol_radius_mm = 12.0
plate_scale = ra_range/75.0/fiber_pitch_mm
method="galaxy_density"
gal_density  = 2.0*(119.0*137.0/(ra_range**2))
mock_gals = AM.MockGalaxyCatalog(number_density=gal_density, ra_range = ra_range, dec_range=ra_range, random=True)
mock_gals.tile_ID[:] = -1
for i in range(5):    
    BB_fibers = AM.FiberSet(Nx=75, Ny=87,fiber_pitch=fiber_pitch_mm * plate_scale, fiber_size=fiber_size_mm * plate_scale, rectangle=True)
    AM.make_fiber_allocation(BB_fibers, mock_gals, visit_ID=i, rank_criterion=method, patrol_radius=patrol_radius_mm * plate_scale,\
                    exclusion_radius=BB_fibers.fiber_size * 0.5)
    allocated_gals = where(mock_gals.visit_ID!=-2)
    n_allocated = size(allocated_gals)
    n_total_gals = 1.0*mock_gals.Ngalaxies
    print 'fraction of allocated galaxies', n_allocated/n_total_gals, n_total_gals, BB_fibers.Nfibers
scatter(BB_fibers.x, BB_fibers.y, color='blue', alpha=1.0, s=1.0)
# Out:
# 3488 fibers were reset
# 2216
#  fibers were reset
# 1165
#  fibers were reset
# 445
#  fibers were reset
# 107
#  fibers were reset
# 17
#  fibers were reset
# 6
#  fibers were reset
# 6
#  fibers were reset
# fraction of allocated galaxies 0.199932527756 32606.0 6525
# 4206
#  fibers were reset
# 2490
#  fibers were reset
# 1189
#  fibers were reset
# 378
#  fibers were reset
# 61
#  fibers were reset
# 13
#  fibers were reset
# 9
#  fibers were reset
# 9
#  fibers were reset
# fraction of allocated galaxies 0.399773047905 32606.0 6525
# 4219
#  fibers were reset
# 2478
#  fibers were reset
# 1183
#  fibers were reset
# 371
#  fibers were reset
# 68
#  fibers were reset
# 7
#  fibers were reset
# 0
#  fibers were reset
# fraction of allocated galaxies 0.599889590873 32606.0 6525
# 4324
#  fibers were reset
# 2690
#  fibers were reset
# 1345
#  fibers were reset
# 503
#  fibers were reset
# 115
#  fibers were reset
# 17
#  fibers were reset
# 9
#  fibers were reset
# 8
#  fibers were reset
# 8
#  fibers were reset
# fraction of allocated galaxies 0.799760780224 32606.0 6525
# 4519
#  fibers were reset
# 2941
#  fibers were reset
# 1671
#  fibers were reset
# 715
#  fibers were reset
# 181
#  fibers were reset
# 36
#  fibers were reset
# 19
#  fibers were reset
# 17
#  fibers were reset
# 17
#  fibers were reset
# fraction of allocated galaxies 0.980218364718 32606.0 6525

# %%
#Poisson - Mohawk
ra_range = 3.0
fiber_pitch_mm = 7.56
fiber_size_mm = 1.2
patrol_radius_mm = 7.56
plate_scale = ra_range/119.0/fiber_pitch_mm
method="galaxy_density"
gal_density  = 2.0*(119.0*137.0/(ra_range**2))
mock_gals = AM.MockGalaxyCatalog(number_density=gal_density, ra_range = ra_range, dec_range=ra_range, random=True)
mock_gals.tile_ID[:] = -1
for i in range(2):    
    BB_fibers = AM.FiberSet(Nx=119, Ny=137,fiber_pitch=fiber_pitch_mm * plate_scale, fiber_size=fiber_size_mm * plate_scale, rectangle=True)
    AM.make_fiber_allocation(BB_fibers, mock_gals, visit_ID=i, rank_criterion=method, patrol_radius=patrol_radius_mm * plate_scale,\
                    exclusion_radius=BB_fibers.fiber_size * 0.5)
    allocated_gals = where(mock_gals.visit_ID!=-2)
    n_allocated = size(allocated_gals)
    n_total_gals = 1.0*mock_gals.Ngalaxies
    print 'fraction of allocated galaxies', n_allocated/n_total_gals, n_total_gals, BB_fibers.Nfibers
scatter(BB_fibers.x, BB_fibers.y, color='blue', alpha=1.0, s=1.0)
# Out:
# 6307 fibers were reset
# 2501
#  fibers were reset
# 507
#  fibers were reset
# 58
#  fibers were reset
# 22
#  fibers were reset
# 21
#  fibers were reset
# 20
#  fibers were reset
# 20
#  fibers were reset
# fraction of allocated galaxies 0.498711893517 32606.0 16303
# 7354
#  fibers were reset
# 2393
#  fibers were reset
# 299
#  fibers were reset
# 78
#  fibers were reset
# 72
#  fibers were reset
# 72
#  fibers were reset
# fraction of allocated galaxies 0.915935717353 32606.0 16303

# %%
#Mock - BigBoss
ra_range = 3.0
fiber_pitch_mm = 7.56
fiber_size_mm = 3.6
patrol_radius_mm = 7.0
plate_scale = ra_range/75.0/fiber_pitch_mm
method="galaxy_density"


date_path="/home/forero/Dropbox/FiberAllocation/data/"
filename = "20130417_gal_cat.dat"
mock_gals = AM.MockGalaxyCatalog(filename=date_path+filename)
mock_gals.tile_ID[:] = -1

for i in range(5):    
    BB_fibers = AM.FiberSet(Nx=75, Ny=87,fiber_pitch=fiber_pitch_mm * plate_scale, fiber_size=fiber_size_mm * plate_scale, rectangle=True)
    AM.make_fiber_allocation(BB_fibers, mock_gals, visit_ID=i, rank_criterion=method, patrol_radius=patrol_radius_mm * plate_scale,\
                    exclusion_radius=BB_fibers.fiber_size * 0.5)
    
    
    allocated_gals = where(mock_gals.visit_ID!=-2)
    n_allocated = size(allocated_gals)
    n_total_gals = 1.0*mock_gals.Ngalaxies
    print 'fraction of allocated galaxies', n_allocated/n_total_gals, n_total_gals, BB_fibers.Nfibers
    
    #check the efficiency by galaxy type 1 - ELG
    allocated_gals_1 = where((mock_gals.visit_ID!=-2) & (mock_gals.gal_type==1))
    n_allocated_1 = 1.0*size(allocated_gals_1)
    n_total_gals_1 = 1.0*size(where(mock_gals.gal_type==1))
    print 'fraction of allocated ELG', n_allocated_1/n_total_gals_1

    #check the efficiency by galaxy type 2 - LRG
    allocated_gals_2 = where((mock_gals.visit_ID!=-2) & (mock_gals.gal_type==2))
    n_allocated_2 = 1.0*size(allocated_gals_2)
    n_total_gals_2 = 1.0*size(where(mock_gals.gal_type==2))
    print 'fraction of allocated LRG', n_allocated_2/n_total_gals_2
# Out:
# Loading /home/forero/Dropbox/FiberAllocation/data/20130417_gal_cat.dat
# (32625,)
# 2344
#  fibers were reset
# 1451
#  fibers were reset
# 818
#  fibers were reset
# 831
#  fibers were reset
# 623
#  fibers were reset
# 830
#  fibers were reset
# fraction of allocated galaxies 0.164168582375 32625.0 6525
# fraction of allocated ELG 0.167065420561
# fraction of allocated LRG 0.150978723404
# 2510
#  fibers were reset
# 1475
#  fibers were reset
# 829
#  fibers were reset
# 922
#  fibers were reset
# 713
#  fibers were reset
# 927
#  fibers were reset
# fraction of allocated galaxies 0.325026819923 32625.0 6525
# fraction of allocated ELG 0.333196261682
# fraction of allocated LRG 0.287829787234
# 2720
#  fibers were reset
# 1605
#  fibers were reset
# 937
#  fibers were reset
# 1038
#  fibers were reset
# 818
#  fibers were reset
# 1037
#  fibers were reset
# 831
#  fibers were reset
# fraction of allocated galaxies 0.482298850575 32625.0 6525
# fraction of allocated ELG 0.495887850467
# fraction of allocated LRG 0.420425531915
# 2869
#  fibers were reset
# 1767
#  fibers were reset
# 1064
#  fibers were reset
# 1136
#  fibers were reset
# 908
#  fibers were reset
# 1126
#  fibers were reset
# 911
#  fibers were reset
# 1108
#  fibers were reset
# fraction of allocated galaxies 0.632122605364 32625.0 6525
# fraction of allocated ELG 0.650579439252
# fraction of allocated LRG 0.548085106383
# 2847
#  fibers were reset
# 1722
#  fibers were reset
# 1094
#  fibers were reset
# 1203
#  fibers were reset
# 974
#  fibers were reset
# 1191
#  fibers were reset
# 988
#  fibers were reset
# fraction of allocated galaxies 0.748107279693 32625.0 6525
# fraction of allocated ELG 0.761158878505
# fraction of allocated LRG 0.688680851064

# %%
#Mock - Echidna
ra_range = 3.0
fiber_pitch_mm = 7.56
fiber_size_mm = 1.2
patrol_radius_mm = 12.0
plate_scale = ra_range/75.0/fiber_pitch_mm
method="galaxy_density"

date_path="/home/forero/Dropbox/FiberAllocation/data/"
filename = "20130417_gal_cat.dat"
mock_gals = AM.MockGalaxyCatalog(filename=date_path+filename)
mock_gals.tile_ID[:] = -1

for i in range(5):    
    BB_fibers = AM.FiberSet(Nx=75, Ny=87,fiber_pitch=fiber_pitch_mm * plate_scale, fiber_size=fiber_size_mm * plate_scale, rectangle=True)
    AM.make_fiber_allocation(BB_fibers, mock_gals, visit_ID=i, rank_criterion=method, patrol_radius=patrol_radius_mm * plate_scale,\
                    exclusion_radius=BB_fibers.fiber_size * 0.5)
    
    
    allocated_gals = where(mock_gals.visit_ID!=-2)
    n_allocated = size(allocated_gals)
    n_total_gals = 1.0*mock_gals.Ngalaxies
    print 'fraction of allocated galaxies', n_allocated/n_total_gals, n_total_gals, BB_fibers.Nfibers
    
    #check the efficiency by galaxy type 1 - ELG
    allocated_gals_1 = where((mock_gals.visit_ID!=-2) & (mock_gals.gal_type==1))
    n_allocated_1 = 1.0*size(allocated_gals_1)
    n_total_gals_1 = 1.0*size(where(mock_gals.gal_type==1))
    print 'fraction of allocated ELG', n_allocated_1/n_total_gals_1

    #check the efficiency by galaxy type 2 - LRG
    allocated_gals_2 = where((mock_gals.visit_ID!=-2) & (mock_gals.gal_type==2))
    n_allocated_2 = 1.0*size(allocated_gals_2)
    n_total_gals_2 = 1.0*size(where(mock_gals.gal_type==2))
    print 'fraction of allocated LRG', n_allocated_2/n_total_gals_2
    
scatter(BB_fibers.x, BB_fibers.y, color='blue', alpha=1.0, s=1.0)
# Out:
# Loading /home/forero/Dropbox/FiberAllocation/data/20130417_gal_cat.dat
# (32625,)
# 3166
#  fibers were reset
# 2333
#  fibers were reset
# 1377
#  fibers were reset
# 1056
#  fibers were reset
# 721
#  fibers were reset
# 828
#  fibers were reset
# 632
#  fibers were reset
# 805
#  fibers were reset
# fraction of allocated galaxies 0.166314176245 32625.0 6525
# fraction of allocated ELG 0.164186915888
# fraction of allocated LRG 0.176
# 3737
#  fibers were reset
# 2531
#  fibers were reset
# 1434
#  fibers were reset
# 1053
#  fibers were reset
# 724
#  fibers were reset
# 870
#  fibers were reset
# 686
#  fibers were reset
# fraction of allocated galaxies 0.33014559387 32625.0 6525
# fraction of allocated ELG 0.32814953271
# fraction of allocated LRG 0.339234042553
# 3925
#  fibers were reset
# 2711
#  fibers were reset
# 1576
#  fibers were reset
# 1077
#  fibers were reset
# 719
#  fibers were reset
# 869
#  fibers were reset
# 671
#  fibers were reset
# 847
#  fibers were reset
# 697
#  fibers were reset
# fraction of allocated galaxies 0.493946360153 32625.0 6525
# fraction of allocated ELG 0.494317757009
# fraction of allocated LRG 0.492255319149
# 3978
#  fibers were reset
# 2930
#  fibers were reset
# 1791
#  fibers were reset
# 1263
#  fibers were reset
# 752
#  fibers were reset
# 890
#  fibers were reset
# 668
#  fibers were reset
# 867
#  fibers were reset
# 698
#  fibers were reset
# fraction of allocated galaxies 0.657379310345 32625.0 6525
# fraction of allocated ELG 0.665943925234
# fraction of allocated LRG 0.618382978723
# 4161
#  fibers were reset
# 3219
#  fibers were reset
# 1984
#  fibers were reset
# 1265
#  fibers were reset
# 768
#  fibers were reset
# 900
#  fibers were reset
# 681
#  fibers were reset
# 872
#  fibers were reset
# 718
#  fibers were reset
# fraction of allocated galaxies 0.791509578544 32625.0 6525
# fraction of allocated ELG 0.797981308411
# fraction of allocated LRG 0.762042553191

# %%
#Poisson - Mohawk
ra_range = 3.0
fiber_pitch_mm = 7.56
fiber_size_mm = 1.2
patrol_radius_mm = 7.56
plate_scale = ra_range/119.0/fiber_pitch_mm
method="galaxy_density"



date_path="/home/forero/Dropbox/FiberAllocation/data/"
filename = "20130417_gal_cat.dat"
mock_gals = AM.MockGalaxyCatalog(filename=date_path+filename)
mock_gals.tile_ID[:] = -1

for i in range(2):    
    BB_fibers = AM.FiberSet(Nx=119, Ny=137,fiber_pitch=fiber_pitch_mm * plate_scale, fiber_size=fiber_size_mm * plate_scale, rectangle=True)
    AM.make_fiber_allocation(BB_fibers, mock_gals, visit_ID=i, rank_criterion=method, patrol_radius=patrol_radius_mm * plate_scale,\
                    exclusion_radius=BB_fibers.fiber_size * 0.5)
    
    #global allocation efficiency
    allocated_gals = where(mock_gals.visit_ID!=-2)
    n_allocated = size(allocated_gals)
    n_total_gals = 1.0*mock_gals.Ngalaxies
    print 'fraction of allocated galaxies', n_allocated/n_total_gals, n_total_gals, BB_fibers.Nfibers
    
    #check the efficiency by galaxy type 1 - ELG
    allocated_gals_1 = where((mock_gals.visit_ID!=-2) & (mock_gals.gal_type==1))
    n_allocated_1 = 1.0*size(allocated_gals_1)
    n_total_gals_1 = 1.0*size(where(mock_gals.gal_type==1))
    print 'fraction of allocated ELG', n_allocated_1/n_total_gals_1

    #check the efficiency by galaxy type 2 - LRG
    allocated_gals_2 = where((mock_gals.visit_ID!=-2) & (mock_gals.gal_type==2))
    n_allocated_2 = 1.0*size(allocated_gals_2)
    n_total_gals_2 = 1.0*size(where(mock_gals.gal_type==2))
    print 'fraction of allocated LRG', n_allocated_2/n_total_gals_2
# Out:
# Loading /home/forero/Dropbox/FiberAllocation/data/20130417_gal_cat.dat
# (32625,)
# 6132
#  fibers were reset
# 3724
#  fibers were reset
# 1913
#  fibers were reset
# 1858
#  fibers were reset
# 1438
#  fibers were reset
# 1863
#  fibers were reset
# fraction of allocated galaxies 0.414130268199 32625.0 16303
# fraction of allocated ELG 0.434691588785
# fraction of allocated LRG 0.320510638298
# 7056
#  fibers were reset
# 3529
#  fibers were reset
# 1743
#  fibers were reset
# 1892
#  fibers were reset
# 1485
#  fibers were reset
# 1914
#  fibers were reset
# fraction of allocated galaxies 0.740720306513 32625.0 16303
# fraction of allocated ELG 0.755476635514
# fraction of allocated LRG 0.673531914894

# %%
scatter(mock_gals.x, mock_gals.y, color='blue', alpha=1.0, s=1.0)

# %%
scatter(BB_fibers.x, BB_fibers.y, color='blue', alpha=1.0, s=1.0)
