# %%
# %pylab inline
import numpy as np
import sys
import AllocationModule as AM
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
plate_scale = 0.27/60. / (15. / 1e3) / 60.0# convert arcsec to arcmin; micron to mm; arcmin to deg --> arcmin/mm --> deg/mm
fiber_pitch_mm = 6.0
fiber_size_mm = 0.7 * 2.0
fibers = AM.FiberSet(Nx=20, Ny=20,fiber_pitch=fiber_pitch_mm * plate_scale, fiber_size=fiber_size_mm * plate_scale, rectangle=True)

# %%
scatter(fibers.x, fibers.y, color='blue', alpha=1.0, s=1.0)

# %%
mock_gals = AM.MockGalaxyCatalog(number_density=300, ra_range = 3.0, dec_range=3.0, random=True)

# %%
scatter(mock_gals.x, mock_gals.y, color='red', alpha=1.0, s=1.0)
