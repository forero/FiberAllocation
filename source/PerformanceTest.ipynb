# %%
# %pylab inline
import numpy as np
import sys
import AllocationModule as AM
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
date_path="/home/forero/Dropbox/FiberAllocation/data/"
filename = "20130417_gal_cat.dat"
mock_gals = AM.MockGalaxyCatalog(filename=date_path+filename)
mock_gals.tile_ID[:] = -1
scatter(mock_gals.x, mock_gals.y, color='blue', alpha=1.0, s=1.0)
print amin(mock_gals.x), amax(mock_gals.x), amin(mock_gals.y), amax(mock_gals.y)
# Out:
# Loading /home/forero/Dropbox/FiberAllocation/data/20130417_gal_cat.dat
# (32625,)
# -1.49994314
#  1.49978518 -1.5 1.5

# %%
ra_range = 3.0
fiber_pitch_mm = 7.56
fiber_size_mm = 1.2
patrol_radius_mm = 7.56
plate_scale = ra_range/119.0/fiber_pitch_mm
method="galaxy_density"
BB_fibers = AM.FiberSet(Nx=119, Ny=137,fiber_pitch=fiber_pitch_mm * plate_scale, fiber_size=fiber_size_mm * plate_scale, rectangle=True)
scatter(BB_fibers.x, BB_fibers.y)
print amax(BB_fibers.x), amin(BB_fibers.x), amin(BB_fibers.y), amax(BB_fibers.y)
print fiber_pitch_mm * plate_scale, BB_fibers.Nfibers+137*2, 119*137, BB_fibers.Ny
# Out:
# 1.5 -1.48739495798 -1.48461497792 1.48461497792
# 0.0252100840336 16577 16303 137

# %%
#Poisson - BigBoss
ra_range = 3.0
fiber_pitch_mm = 7.56
fiber_size_mm = 3.6
patrol_radius_mm = 7.0
plate_scale = ra_range/75.0/fiber_pitch_mm
method="galaxy_density"
gal_density  = 2.0*(119.0*137.0/(ra_range**2))
mock_gals = AM.MockGalaxyCatalog(number_density=gal_density, ra_range = ra_range, dec_range=ra_range, random=True)
mock_gals.tile_ID[:] = -1
for i in range(5):    
    BB_fibers = AM.FiberSet(Nx=75, Ny=87,fiber_pitch=fiber_pitch_mm * plate_scale, fiber_size=fiber_size_mm * plate_scale, rectangle=True)
    AM.make_fiber_allocation(BB_fibers, mock_gals, visit_ID=i, rank_criterion=method, patrol_radius=patrol_radius_mm * plate_scale,\
                    exclusion_radius=BB_fibers.fiber_size * 0.5)
    allocated_gals = where(mock_gals.visit_ID!=-2)
    n_allocated = size(allocated_gals)
    n_total_gals = 1.0*mock_gals.Ngalaxies
    print 'fraction of allocated galaxies', n_allocated/n_total_gals, n_total_gals, BB_fibers.Nfibers
scatter(BB_fibers.x, BB_fibers.y, color='blue', alpha=1.0, s=1.0)
# Out:
# 2431 fibers were reset
# 981
#  fibers were reset
# 336
#  fibers were reset
# 189
#  fibers were reset
# 167
#  fibers were reset
# 166
#  fibers were reset
# 165
#  fibers were reset
# fraction of allocated galaxies 0.195025455438 32606.0 6525
# 2741
#  fibers were reset
# 1037
#  fibers were reset
# 372
#  fibers were reset
# 287
#  fibers were reset
# 273
#  fibers were reset
# 273
#  fibers were reset
# 272
#  fibers were reset
# fraction of allocated galaxies 0.386738637061 32606.0 6525
# 2964
#  fibers were reset
# 1229
#  fibers were reset
# 482
#  fibers were reset
# 334
#  fibers were reset
# 317
#  fibers were reset
# 316
#  fibers were reset
# 315
#  fibers were reset
# 315
#  fibers were reset
# fraction of allocated galaxies 0.577133042998 32606.0 6525
# 3027
#  fibers were reset
# 1239
#  fibers were reset
# 512
#  fibers were reset
# 394
#  fibers were reset
# 375
#  fibers were reset
# 375
#  fibers were reset
# ...

# %%
#Poisson - Echidna
ra_range = 3.0
fiber_pitch_mm = 7.56
fiber_size_mm = 1.2
patrol_radius_mm = 12.0
plate_scale = ra_range/75.0/fiber_pitch_mm
method="galaxy_density"
gal_density  = 2.0*(119.0*137.0/(ra_range**2))
mock_gals = AM.MockGalaxyCatalog(number_density=gal_density, ra_range = ra_range, dec_range=ra_range, random=True)
mock_gals.tile_ID[:] = -1
for i in range(5):    
    BB_fibers = AM.FiberSet(Nx=75, Ny=87,fiber_pitch=fiber_pitch_mm * plate_scale, fiber_size=fiber_size_mm * plate_scale, rectangle=True)
    AM.make_fiber_allocation(BB_fibers, mock_gals, visit_ID=i, rank_criterion=method, patrol_radius=patrol_radius_mm * plate_scale,\
                    exclusion_radius=BB_fibers.fiber_size * 0.5)
    allocated_gals = where(mock_gals.visit_ID!=-2)
    n_allocated = size(allocated_gals)
    n_total_gals = 1.0*mock_gals.Ngalaxies
    print 'fraction of allocated galaxies', n_allocated/n_total_gals, n_total_gals, BB_fibers.Nfibers
scatter(BB_fibers.x, BB_fibers.y, color='blue', alpha=1.0, s=1.0)
# Out:
# 3437 fibers were reset
# 2168
#  fibers were reset
# 1121
#  fibers were reset
# 443
#  fibers were reset
# 119
#  fibers were reset
# 20
#  fibers were reset
# 6
#  fibers were reset
# 6
#  fibers were reset
# fraction of allocated galaxies 0.199932527756 32606.0 6525
# 4147
#  fibers were reset
# 2431
#  fibers were reset
# 1088
#  fibers were reset
# 327
#  fibers were reset
# 51
#  fibers were reset
# 7
#  fibers were reset
# 0
#  fibers were reset
# fraction of allocated galaxies 0.400049070723 32606.0 6525
# 4256
#  fibers were reset
# 2522
#  fibers were reset
# 1181
#  fibers were reset
# 357
#  fibers were reset
# 68
#  fibers were reset
# 12
#  fibers were reset
# 4
#  fibers were reset
# 2
#  fibers were reset
# 2
#  fibers were reset
# fraction of allocated galaxies 0.600104275287 32606.0 6525
# 4293
#  fibers were reset
# 2698
#  fibers were reset
# 1373
#  fibers were reset
# 493
#  fibers were reset
# 119
#  fibers were reset
# 20
#  fibers were reset
# 13
# ...

# %%
#Poisson - Mohawk
ra_range = 3.0
fiber_pitch_mm = 7.56
fiber_size_mm = 1.2
patrol_radius_mm = 7.56
plate_scale = ra_range/119.0/fiber_pitch_mm
method="galaxy_density"
gal_density  = 2.0*(119.0*137.0/(ra_range**2))
mock_gals = AM.MockGalaxyCatalog(number_density=gal_density, ra_range = ra_range, dec_range=ra_range, random=True)
mock_gals.tile_ID[:] = -1
for i in range(2):    
    BB_fibers = AM.FiberSet(Nx=119, Ny=137,fiber_pitch=fiber_pitch_mm * plate_scale, fiber_size=fiber_size_mm * plate_scale, rectangle=True)
    AM.make_fiber_allocation(BB_fibers, mock_gals, visit_ID=i, rank_criterion=method, patrol_radius=patrol_radius_mm * plate_scale,\
                    exclusion_radius=BB_fibers.fiber_size * 0.5)
    allocated_gals = where(mock_gals.visit_ID!=-2)
    n_allocated = size(allocated_gals)
    n_total_gals = 1.0*mock_gals.Ngalaxies
    print 'fraction of allocated galaxies', n_allocated/n_total_gals, n_total_gals, BB_fibers.Nfibers
scatter(BB_fibers.x, BB_fibers.y, color='blue', alpha=1.0, s=1.0)
# Out:
# 6283 fibers were reset
# 2521
#  fibers were reset
# 552
#  fibers were reset
# 71
#  fibers were reset
# 33
#  fibers were reset
# 31
#  fibers were reset
# 31
#  fibers were reset
# fraction of allocated galaxies 0.498558547507 32606.0 16303
# 7419
#  fibers were reset
# 2406
#  fibers were reset
# 257
#  fibers were reset
# 45
#  fibers were reset
# 38
#  fibers were reset
# 37
#  fibers were reset
# fraction of allocated galaxies 0.918143899896 32606.0 16303

# %%
#Mock - BigBoss
ra_range = 3.0
fiber_pitch_mm = 7.56
fiber_size_mm = 3.6
patrol_radius_mm = 7.0
plate_scale = ra_range/75.0/fiber_pitch_mm
method="galaxy_density"


date_path="/home/forero/Dropbox/FiberAllocation/data/"
filename = "20130417_gal_cat.dat"
mock_gals = AM.MockGalaxyCatalog(filename=date_path+filename)
mock_gals.tile_ID[:] = -1

for i in range(5):    
    BB_fibers = AM.FiberSet(Nx=75, Ny=87,fiber_pitch=fiber_pitch_mm * plate_scale, fiber_size=fiber_size_mm * plate_scale, rectangle=True)
    AM.make_fiber_allocation(BB_fibers, mock_gals, visit_ID=i, rank_criterion=method, patrol_radius=patrol_radius_mm * plate_scale,\
                    exclusion_radius=BB_fibers.fiber_size * 0.5)
    
    
    allocated_gals = where(mock_gals.visit_ID!=-2)
    n_allocated = size(allocated_gals)
    n_total_gals = 1.0*mock_gals.Ngalaxies
    print 'fraction of allocated galaxies', n_allocated/n_total_gals, n_total_gals, BB_fibers.Nfibers
    
    #check the efficiency by galaxy type 1 - ELG
    allocated_gals_1 = where((mock_gals.visit_ID!=-2) & (mock_gals.gal_type==1))
    n_allocated_1 = 1.0*size(allocated_gals_1)
    n_total_gals_1 = 1.0*size(where(mock_gals.gal_type==1))
    print 'fraction of allocated ELG', n_allocated_1/n_total_gals_1

    #check the efficiency by galaxy type 2 - LRG
    allocated_gals_2 = where((mock_gals.visit_ID!=-2) & (mock_gals.gal_type==2))
    n_allocated_2 = 1.0*size(allocated_gals_2)
    n_total_gals_2 = 1.0*size(where(mock_gals.gal_type==2))
    print 'fraction of allocated LRG', n_allocated_2/n_total_gals_2
# Out:
# Loading /home/forero/Dropbox/FiberAllocation/data/20130417_gal_cat.dat
# (32625,)
# 2344
#  fibers were reset
# 1451
#  fibers were reset
# 818
#  fibers were reset
# 831
#  fibers were reset
# 623
#  fibers were reset
# 830
#  fibers were reset
# fraction of allocated galaxies 0.164168582375 32625.0 6525
# fraction of allocated ELG 0.167065420561
# fraction of allocated LRG 0.150978723404
# 2510
#  fibers were reset
# 1475
#  fibers were reset
# 829
#  fibers were reset
# 922
#  fibers were reset
# 713
#  fibers were reset
# 927
#  fibers were reset
# fraction of allocated galaxies 0.325026819923 32625.0 6525
# fraction of allocated ELG 0.333196261682
# fraction of allocated LRG 0.287829787234
# 2720
#  fibers were reset
# 1605
#  fibers were reset
# 937
#  fibers were reset
# 1038
#  fibers were reset
# 818
#  fibers were reset
# 1037
#  fibers were reset
# 831
#  fibers were reset
# fraction of allocated galaxies 0.482298850575 32625.0 6525
# ...

# %%
#Mock - Echidna
ra_range = 3.0
fiber_pitch_mm = 7.56
fiber_size_mm = 1.2
patrol_radius_mm = 12.0
plate_scale = ra_range/75.0/fiber_pitch_mm
method="galaxy_density"

date_path="/home/forero/Dropbox/FiberAllocation/data/"
filename = "20130417_gal_cat.dat"
mock_gals = AM.MockGalaxyCatalog(filename=date_path+filename)
mock_gals.tile_ID[:] = -1

for i in range(5):    
    BB_fibers = AM.FiberSet(Nx=75, Ny=87,fiber_pitch=fiber_pitch_mm * plate_scale, fiber_size=fiber_size_mm * plate_scale, rectangle=True)
    AM.make_fiber_allocation(BB_fibers, mock_gals, visit_ID=i, rank_criterion=method, patrol_radius=patrol_radius_mm * plate_scale,\
                    exclusion_radius=BB_fibers.fiber_size * 0.5)
    
    
    allocated_gals = where(mock_gals.visit_ID!=-2)
    n_allocated = size(allocated_gals)
    n_total_gals = 1.0*mock_gals.Ngalaxies
    print 'fraction of allocated galaxies', n_allocated/n_total_gals, n_total_gals, BB_fibers.Nfibers
    
    #check the efficiency by galaxy type 1 - ELG
    allocated_gals_1 = where((mock_gals.visit_ID!=-2) & (mock_gals.gal_type==1))
    n_allocated_1 = 1.0*size(allocated_gals_1)
    n_total_gals_1 = 1.0*size(where(mock_gals.gal_type==1))
    print 'fraction of allocated ELG', n_allocated_1/n_total_gals_1

    #check the efficiency by galaxy type 2 - LRG
    allocated_gals_2 = where((mock_gals.visit_ID!=-2) & (mock_gals.gal_type==2))
    n_allocated_2 = 1.0*size(allocated_gals_2)
    n_total_gals_2 = 1.0*size(where(mock_gals.gal_type==2))
    print 'fraction of allocated LRG', n_allocated_2/n_total_gals_2
    
scatter(BB_fibers.x, BB_fibers.y, color='blue', alpha=1.0, s=1.0)
# Out:
# Loading /home/forero/Dropbox/FiberAllocation/data/20130417_gal_cat.dat
# (32625,)
# 3166
#  fibers were reset
# 2333
#  fibers were reset
# 1377
#  fibers were reset
# 1056
#  fibers were reset
# 721
#  fibers were reset
# 828
#  fibers were reset
# 632
#  fibers were reset
# 805
#  fibers were reset
# fraction of allocated galaxies 0.166314176245 32625.0 6525
# fraction of allocated ELG 0.164186915888
# fraction of allocated LRG 0.176
# 3737
#  fibers were reset
# 2531
#  fibers were reset
# 1434
#  fibers were reset
# 1053
#  fibers were reset
# 724
#  fibers were reset
# 870
#  fibers were reset
# 686
#  fibers were reset
# fraction of allocated galaxies 0.33014559387 32625.0 6525
# fraction of allocated ELG 0.32814953271
# fraction of allocated LRG 0.339234042553
# 3925
#  fibers were reset
# 2711
#  fibers were reset
# 1576
#  fibers were reset
# 1077
#  fibers were reset
# 719
#  fibers were reset
# 869
#  fibers were reset
# 671
#  fibers were reset
# 847
#  fibers were reset
# ...

# %%
#Poisson - Mohawk
ra_range = 3.0
fiber_pitch_mm = 7.56
fiber_size_mm = 1.2
patrol_radius_mm = 7.56
plate_scale = ra_range/119.0/fiber_pitch_mm
method="galaxy_density"



date_path="/home/forero/Dropbox/FiberAllocation/data/"
filename = "20130417_gal_cat.dat"
mock_gals = AM.MockGalaxyCatalog(filename=date_path+filename)
mock_gals.tile_ID[:] = -1

for i in range(2):    
    BB_fibers = AM.FiberSet(Nx=119, Ny=137,fiber_pitch=fiber_pitch_mm * plate_scale, fiber_size=fiber_size_mm * plate_scale, rectangle=True)
    AM.make_fiber_allocation(BB_fibers, mock_gals, visit_ID=i, rank_criterion=method, patrol_radius=patrol_radius_mm * plate_scale,\
                    exclusion_radius=BB_fibers.fiber_size * 0.5)
    
    #global allocation efficiency
    allocated_gals = where(mock_gals.visit_ID!=-2)
    n_allocated = size(allocated_gals)
    n_total_gals = 1.0*mock_gals.Ngalaxies
    print 'fraction of allocated galaxies', n_allocated/n_total_gals, n_total_gals, BB_fibers.Nfibers
    
    #check the efficiency by galaxy type 1 - ELG
    allocated_gals_1 = where((mock_gals.visit_ID!=-2) & (mock_gals.gal_type==1))
    n_allocated_1 = 1.0*size(allocated_gals_1)
    n_total_gals_1 = 1.0*size(where(mock_gals.gal_type==1))
    print 'fraction of allocated ELG', n_allocated_1/n_total_gals_1

    #check the efficiency by galaxy type 2 - LRG
    allocated_gals_2 = where((mock_gals.visit_ID!=-2) & (mock_gals.gal_type==2))
    n_allocated_2 = 1.0*size(allocated_gals_2)
    n_total_gals_2 = 1.0*size(where(mock_gals.gal_type==2))
    print 'fraction of allocated LRG', n_allocated_2/n_total_gals_2
# Out:
# Loading /home/forero/Dropbox/FiberAllocation/data/20130417_gal_cat.dat
# (32625,)
# 6132
#  fibers were reset
# 3724
#  fibers were reset
# 1913
#  fibers were reset
# 1858
#  fibers were reset
# 1438
#  fibers were reset
# 1863
#  fibers were reset
# fraction of allocated galaxies 0.414130268199 32625.0 16303
# fraction of allocated ELG 0.434691588785
# fraction of allocated LRG 0.320510638298
# 7056
#  fibers were reset
# 3529
#  fibers were reset
# 1743
#  fibers were reset
# 1892
#  fibers were reset
# 1485
#  fibers were reset
# 1914
#  fibers were reset
# fraction of allocated galaxies 0.740720306513 32625.0 16303
# fraction of allocated ELG 0.755476635514
# fraction of allocated LRG 0.673531914894

# %%
scatter(mock_gals.x, mock_gals.y, color='blue', alpha=1.0, s=1.0)

# %%
scatter(BB_fibers.x, BB_fibers.y, color='blue', alpha=1.0, s=1.0)
